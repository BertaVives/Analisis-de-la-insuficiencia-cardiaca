# %%
import pandas as pd

# %%
file = '../data/heart_failure_clinical_records_dataset.csv'
data = pd.read_csv(file, delimiter=',')
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data.columns = ['Age', 'HasAnaemia', 'CPK', 'HasDiabetes',
       'EjectionFraction', 'HasHypertension', 'Platelets',
       'SerumCreatinine', 'SerumSodium', 'Sex', 'Smoking', 'Follow-up',
       'PatientDeceased']
data
# Out:
#       Age  HasAnaemia   CPK  HasDiabetes  EjectionFraction  HasHypertension  \
# 0    75.0           0   582            0                20                1
# 1    55.0           0  7861            0                38                0
# 2    65.0           0   146            0                20                0
# 3    50.0           1   111            0                20                0
# 4    65.0           1   160            1                20                0
# ..    ...         ...   ...          ...               ...              ...
# 294  62.0           0    61            1                38                1
# 295  55.0           0  1820            0                38                0
# 296  45.0           0  2060            1                60                0
# 297  45.0           0  2413            0                38                0
# 298  50.0           0   196            0                45                0
#
# ...

# %%
data.Sex = data.Sex.apply(lambda x: 'female' if x == 0 else 'male')

# %%
data = data.astype({'Age': 'int64', 'HasAnaemia': 'bool', 'HasDiabetes': 'bool', 'HasHypertension': 'bool', 'Smoking': 'bool','PatientDeceased': 'bool'})

# %%
data
# Out:
#      Age  HasAnaemia   CPK  HasDiabetes  EjectionFraction  HasHypertension  \
# 0     75       False   582        False                20             True
# 1     55       False  7861        False                38            False
# 2     65       False   146        False                20            False
# 3     50        True   111        False                20            False
# 4     65        True   160         True                20            False
# ..   ...         ...   ...          ...               ...              ...
# 294   62       False    61         True                38             True
# 295   55       False  1820        False                38            False
# 296   45       False  2060         True                60            False
# 297   45       False  2413        False                38            False
# 298   50       False   196        False                45            False
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               299 non-null    int64
#  1   HasAnaemia        299 non-null    bool
#  2   CPK               299 non-null    int64
#  3   HasDiabetes       299 non-null    bool
#  4   EjectionFraction  299 non-null    int64
#  5   HasHypertension   299 non-null    bool
#  6   Platelets         299 non-null    float64
#  7   SerumCreatinine   299 non-null    float64
#  8   SerumSodium       299 non-null    int64
#  9   Sex               299 non-null    object
#  10  Smoking           299 non-null    bool
#  11  Follow-up         299 non-null    int64
#  12  PatientDeceased   299 non-null    bool
# dtypes: bool(5), float64(2), int64(5), object(1)
# memory usage: 20.3+ KB

# %%
data.describe()
# Out:
#               Age          CPK  EjectionFraction      Platelets  \
# count  299.000000   299.000000        299.000000     299.000000
# mean    60.829431   581.839465         38.083612  263358.029264
# std     11.894997   970.287881         11.834841   97804.236869
# min     40.000000    23.000000         14.000000   25100.000000
# 25%     51.000000   116.500000         30.000000  212500.000000
# 50%     60.000000   250.000000         38.000000  262000.000000
# 75%     70.000000   582.000000         45.000000  303500.000000
# max     95.000000  7861.000000         80.000000  850000.000000
#
#        SerumCreatinine  SerumSodium   Follow-up
# count        299.00000   299.000000  299.000000
# mean           1.39388   136.625418  130.260870
# std            1.03451     4.412477   77.614208
# min            0.50000   113.000000    4.000000
# 25%            0.90000   134.000000   73.000000
# 50%            1.10000   137.000000  115.000000
# 75%            1.40000   140.000000  203.000000
# ...

# %%
# Miramos si tenemos algun null o NaN o none
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <AxesSubplot: >

# %%
import seaborn as sns

sns.heatmap(data.corr())
# Out:
# /var/folders/2l/vvs13szs5gxbhbsk5mznxk800000gn/T/ipykernel_56756/458572859.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <AxesSubplot: >
